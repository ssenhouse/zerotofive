# %% [markdown]
# PLEASE FILL IN SECTIONS BELOW, REPLACING ITALIC TEXT WITH YOUR CONTENT
#
# # Introduction
# The data source is Census data that quantifies several attributes of commute practices in Orange County of workers aged 16 and up. To understand the values contained in the census data file, you need to reference the following files:
#
# //zerotofive/ACSST5Y2021.S0801-Column-Metadata_THIS IS THE KEY.csv - shows the flat hierarchy of the data set
# //zerotofive/S0801.xlsx - shows the value definition (e.g time in minutes, % of responded Yes/No)
#
#
#
# ## Questions to answer
#
# - What is the average commute time to work within Orange County
# -
#
# # Setup
# ## Data
# VERY, VERY IMPORTANT PLEASE PROVIDE DEATILS ABOUT THE DATA YOU USED AND HOW TO GET IT SO OTHERS CAN RUN THIS AMAZING NOTEBOOK TOO
#
# |Dataset               | Type           | Description                                     |  Where to get the data |
# |----------------------|----------------|-------------------------------------------------|------------------------|
# |                      |                |                                                 |                        |
# |                      |                |                                                 |                        |
# |                      |                |                                                 |                        |
#
#
#
# ## Environment
# PLEASE RUN THE PANEL BELOW SO OTHERS KNOW EXACTLY THE ENVIRONMENT

# %%
# Add package installs here, for example ...
# !pip install pycurl

#!python -V
#!pip list

# list of package dependencies and their pip install commands
#!pip install geopandas
#!pip install census
#!pip install us
#!pip install geopandas hvplot
#!pip install cartopy geoviews

# %%
# Add imports here
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import geopandas as gpd
import hvplot.pandas
import holoviews as hv
import geoviews as gv
import matplotlib.cm as cm
hv.extension('bokeh')
import os
import re
from census import Census
from us import states
from pathlib import Path
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Settings
# PLEASE USE VARIABLES FOR THINGS LIKE FILE LOCATIONS AND CONFIGURATION SETTINGS

# %%
# Some examples ...
#DATA_DIRECTORY = './/'
#USER_NAME = ''

# Please always use environment variables for sensative credentials, never commit credentials to github
#USER_PASSWORD = os.environ['USER_PASSWORD']

# %% [markdown]
# ## Data

# %%
# Put code here for getting your data. Use tools such as curl and wget if data is available online
# used data provided from US census. Downloaded csv file to local machine. 
# input csv file and put into dataframe

csvpath = Path("ACSST5Y2021.S0801-Data.csv")

#read in csv file and set to dataframe
commute_df = pd.read_csv(csvpath)

#show dataframe
commute_df.head()
# Out:
#                  GEO_ID                                         NAME  \
# 0             Geography                         Geographic Area Name
# 1  1400000US12095010201  Census Tract 102.01, Orange County, Florida
# 2  1400000US12095010202  Census Tract 102.02, Orange County, Florida
# 3  1400000US12095010300     Census Tract 103, Orange County, Florida
# 4  1400000US12095010400     Census Tract 104, Orange County, Florida
#
#                                S0801_C01_001E  \
# 0  Estimate!!Total!!Workers 16 years and over
# 1                                        1315
# 2                                        2441
# 3                                        1515
# 4                                         333
#
#                                       S0801_C01_001M  \
# 0  Margin of Error!!Total!!Workers 16 years and over
# 1                                                305
# 2                                                459
# 3                                                279
# 4                                                 80
#
#                                      S0801_C01_001MA  \
# 0  Annotation of Margin of Error!!Total!!Workers ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      S0801_C01_001EA  \
# 0  Annotation of Estimate!!Total!!Workers 16 year...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       S0801_C01_002E  \
# 0  Estimate!!Total!!Workers 16 years and over!!ME...
# 1                                               73.2
# 2                                               70.5
# 3                                               82.1
# 4                                               71.8
#
#                                       S0801_C01_002M  \
# 0  Margin of Error!!Total!!Workers 16 years and o...
# 1                                               10.1
# 2                                                7.5
# 3                                                7.3
# 4                                               15.2
#
#                                      S0801_C01_002MA  \
# 0  Annotation of Margin of Error!!Total!!Workers ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      S0801_C01_002EA  ...  \
# 0  Annotation of Estimate!!Total!!Workers 16 year...  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#                                      S0801_C03_055EA  \
# 0  Annotation of Estimate!!Female!!PERCENT ALLOCA...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S0801_C03_056E  \
# 0  Estimate!!Female!!PERCENT ALLOCATED!!Travel ti...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S0801_C03_056M  \
# 0  Margin of Error!!Female!!PERCENT ALLOCATED!!Tr...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      S0801_C03_056MA  \
# 0  Annotation of Margin of Error!!Female!!PERCENT...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      S0801_C03_056EA  \
# 0  Annotation of Estimate!!Female!!PERCENT ALLOCA...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S0801_C03_057E  \
# 0  Estimate!!Female!!PERCENT ALLOCATED!!Vehicles ...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                       S0801_C03_057M  \
# 0  Margin of Error!!Female!!PERCENT ALLOCATED!!Ve...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      S0801_C03_057MA  \
# 0  Annotation of Margin of Error!!Female!!PERCENT...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      S0801_C03_057EA Unnamed: 686
# 0  Annotation of Estimate!!Female!!PERCENT ALLOCA...          NaN
# 1                                                (X)          NaN
# 2                                                (X)          NaN
# 3                                                (X)          NaN
# 4                                                (X)          NaN
#
# [5 rows x 687 columns]

# %%
# input census tract cross walk file. 
# This file will used to map the census data on commuting habits to the data a Lat and Long for plotting charts

csvpath = Path("florida_census_map.csv")

#read in csv file and set to dataframe
flmap_df = pd.read_csv(csvpath)

#show dataframe
flmap_df.head()
# Out:
#    MTFCC           OID        GEOID  STATE  COUNTY  TRACT  BASENAME  \
# 0  G5020  2.079020e+15  12001000201     12       1    201      2.01
# 1  G5020  2.079020e+15  12001000202     12       1    202      2.02
# 2  G5020  2.079040e+14  12001000301     12       1    301      3.01
# 3  G5020  2.079040e+14  12001000302     12       1    302      3.02
# 4  G5020  2.079030e+13  12001000400     12       1    400      4.00
#
#                 NAME LSADC FUNCSTAT   AREALAND  AREAWATER  UR    CENTLAT  \
# 0  Census Tract 2.01    CT        S  1238506.0        NaN NaN  29.654541
# 1  Census Tract 2.02    CT        S   857504.0        NaN NaN  29.646160
# 2  Census Tract 3.01    CT        S  2479034.0    22169.0 NaN  29.666687
# 3  Census Tract 3.02    CT        S  3819522.0    14011.0 NaN  29.683592
# 4     Census Tract 4    CT        S  6010490.0    18712.0 NaN  29.677786
#
#      CENTLON   INTPTLAT   INTPTLON
# 0 -82.333741  29.654541 -82.333741
# 1 -82.332953  29.646160 -82.332953
# 2 -82.331211  29.668004 -82.331418
# 3 -82.330501  29.684245 -82.330056
# 4 -82.307876  29.679476 -82.308121

# %%
flmap_df.dtypes
# Out:
# MTFCC         object
# OID          float64
# GEOID          int64
# STATE          int64
# COUNTY         int64
# TRACT          int64
# BASENAME     float64
# NAME          object
# LSADC         object
# FUNCSTAT      object
# AREALAND     float64
# AREAWATER    float64
# UR           float64
# CENTLAT      float64
# CENTLON      float64
# INTPTLAT     float64
# INTPTLON     float64
# dtype: object

# %%
# check the number of rows and columns in the dataframe
commute_df.shape
# Out:
# (268, 687)

# %%
# check the variable type in the dataframe
commute_df.dtypes
# Out:
# GEO_ID              object
# NAME                object
# S0801_C01_001E      object
# S0801_C01_001M      object
# S0801_C01_001MA     object
#                     ...
# S0801_C03_057E      object
# S0801_C03_057M      object
# S0801_C03_057MA     object
# S0801_C03_057EA     object
# Unnamed: 686       float64
# Length: 687, dtype: object

# %%
# input provider location file. 
# This file will used to map the census data on commuting habits to the data a Lat and Long for plotting charts

csvpath = Path('providerlocations_output.csv')

#read in csv file and set to dataframe
provider_df = pd.read_csv(csvpath)

#show dataframe
provider_df.head()
# Out:
#      TIGER OUTPUT ADDRESS     City State    Zip        LON        LAT
# 0  23 N WEKIWA SPRINGS RD   APOPKA    FL  32703 -81.467950  28.679436
# 1      305 S HIGHLAND AVE   APOPKA    FL  32703 -81.505287  28.673929
# 2       204 S CENTRAL AVE   APOPKA    FL  32703 -81.511591  28.675423
# 3    2484 COBBLEFIELD CIR   APOPKA    FL  32703 -81.492383  28.642408
# 4     2505 E SEMORAN BLVD   APOPKA    FL  32703 -81.464734  28.673026

# %% [markdown]
# ## Data Cleaning
# The metadata file describes the values in each column in the csv file. These files helped to determine the variables and the measures that are contained in the census data:
#
# - Path to file ".//zerotofive/ACSST5Y2021.S0801-Column-Metadata_THIS IS THE KEY.csv This file is to translate the column names to understand the measures in the data frame
# - Path to file ".//zerotofive/S0801.xlsx This file is used to understand the value measures in the columns. e.g. percentages vs. absolute count value measures.
#
# The measures follow the following nomenclature:
# - S0801 - This is the Table Name
# - C01 - This is the segment e.g. C01 = Total, C02 = Men, C03 = Women
# - 046E - This is the measure estimate e.g 046E is the Total Average Travel Time for a worker
#
# Consult this file to determine which measure is needed. ilable

# %%
#remove columns with NaN values from the census commuting data
commute_df_clean = commute_df.dropna(axis = 'columns')

commute_df_clean.shape
# Out:
# (268, 374)

# %% [markdown]
# ### Setting up the Average Commute Time DataFrame

# %%
# select columns that correspond to data on average travel time to work by sex
# data can be summarized to calculate the overall average commute times within orange county

avg_time_df = commute_df_clean.loc[ :,['GEO_ID','S0801_C01_046E','S0801_C02_046E','S0801_C03_046E']]

# view dataframe to validate dataframe slice
pd.concat([avg_time_df.head(), avg_time_df.tail()])
# Out:
#                    GEO_ID                                     S0801_C01_046E  \
# 0               Geography  Estimate!!Total!!Workers 16 years and over who...
# 1    1400000US12095010201                                               22.1
# 2    1400000US12095010202                                               24.8
# 3    1400000US12095010300                                               20.7
# 4    1400000US12095010400                                               44.6
# 263  1400000US12095018800                                               24.5
# 264  1400000US12095018901                                               17.0
# 265  1400000US12095018902                                               29.0
# 266  1400000US12095019000                                               22.7
# 267  1400000US12095990000                                                  -
#
#                                         S0801_C02_046E  \
# 0    Estimate!!Male!!Workers 16 years and over who ...
# 1                                                 26.0
# 2                                                 20.6
# 3                                                 22.1
# 4                                                 58.1
# 263                                               24.7
# 264                                               18.2
# 265                                               31.1
# 266                                               25.0
# 267                                                  -
#
#                                         S0801_C03_046E
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                 18.5
# 2                                                 30.9
# 3                                                 19.1
# 4                                                 27.3
# 263                                               24.3
# 264                                               16.0
# 265                                               26.6
# 266                                               20.6
# 267                                                  -

# %%
# selecting the columns from the dataframe that correspond to commute time in minutes
# convert the commute times in minutes from an python object to a numerical value

numbr_cols = avg_time_df[['S0801_C01_046E','S0801_C02_046E','S0801_C03_046E']]

#converting values from string to float
for cols in numbr_cols:
    try:
        avg_time_df[cols]= pd.to_numeric(avg_time_df[cols],errors = 'coerce')
    except ValueError:
        pass 

avg_time_df.dtypes
# Out:
# GEO_ID             object
# S0801_C01_046E    float64
# S0801_C02_046E    float64
# S0801_C03_046E    float64
# dtype: object

# %%
# renaming the dataframe columns to meaningful names 
avg_time_df = avg_time_df.rename(columns ={'S0801_C01_046E':'Total_Workers_Commute_Time','S0801_C02_046E':'Male_Workers_Commute_Time',
                                           'S0801_C03_046E' :'Female_Workers_Commute_Time'})
avg_time_df.head()
# Out:
#                  GEO_ID  Total_Workers_Commute_Time  \
# 0             Geography                         NaN
# 1  1400000US12095010201                        22.1
# 2  1400000US12095010202                        24.8
# 3  1400000US12095010300                        20.7
# 4  1400000US12095010400                        44.6
#
#    Male_Workers_Commute_Time  Female_Workers_Commute_Time
# 0                        NaN                          NaN
# 1                       26.0                         18.5
# 2                       20.6                         30.9
# 3                       22.1                         19.1
# 4                       58.1                         27.3

# %%
# remove the first row from the dataframe
avg_time_df.drop(0, inplace = True)

# %%
# drop all of the na values in the dataframe
avg_time_df.dropna()
# Out:
#                    GEO_ID  Total_Workers_Commute_Time  \
# 1    1400000US12095010201                        22.1
# 2    1400000US12095010202                        24.8
# 3    1400000US12095010300                        20.7
# 4    1400000US12095010400                        44.6
# 5    1400000US12095010500                        38.1
# ..                    ...                         ...
# 262  1400000US12095018700                        27.5
# 263  1400000US12095018800                        24.5
# 264  1400000US12095018901                        17.0
# 265  1400000US12095018902                        29.0
# 266  1400000US12095019000                        22.7
#
#      Male_Workers_Commute_Time  Female_Workers_Commute_Time
# 1                         26.0                         18.5
# 2                         20.6                         30.9
# 3                         22.1                         19.1
# 4                         58.1                         27.3
# 5                         24.6                         44.8
# ..                         ...                          ...
# 262                       24.3                         30.0
# 263                       24.7                         24.3
# 264                       18.2                         16.0
# 265                       31.1                         26.6
# 266                       25.0                         20.6
#
# [265 rows x 4 columns]

# %% [markdown]
# ### Setting up the Travel Time to Work

# %%
# select columns that correspond to data on average travel time to work by sex
# data can be summarized to calculate the overall average commute times within orange county

travel_time_cols =[]
travel_time_cols = ['S0801_C01_037E','S0801_C01_038E','S0801_C01_039E','S0801_C01_040E','S0801_C01_041E','S0801_C01_042E','S0801_C01_043E','S0801_C01_044E','S0801_C01_045E',
                   'S0801_C02_037E','S0801_C02_038E','S0801_C02_039E','S0801_C02_040E','S0801_C02_041E','S0801_C02_042E','S0801_C02_043E','S0801_C02_044E','S0801_C02_045E',
                   'S0801_C03_037E','S0801_C03_038E','S0801_C03_039E','S0801_C03_040E','S0801_C03_041E','S0801_C03_042E','S0801_C03_043E','S0801_C03_044E','S0801_C03_045E',]

travel_time_df = commute_df_clean[['GEO_ID']+ travel_time_cols]

# view dataframe to validate dataframe slice
pd.concat([travel_time_df.head(), travel_time_df.tail()])
# Out:
#                    GEO_ID                                     S0801_C01_037E  \
# 0               Geography  Estimate!!Total!!Workers 16 years and over who...
# 1    1400000US12095010201                                               25.8
# 2    1400000US12095010202                                               16.0
# 3    1400000US12095010300                                                9.0
# 4    1400000US12095010400                                               24.9
# 263  1400000US12095018800                                               10.6
# 264  1400000US12095018901                                               29.1
# 265  1400000US12095018902                                               10.8
# 266  1400000US12095019000                                               10.3
# 267  1400000US12095990000                                                  -
#
#                                         S0801_C01_038E  \
# 0    Estimate!!Total!!Workers 16 years and over who...
# 1                                                 10.2
# 2                                                 13.9
# 3                                                 18.6
# 4                                                  4.0
# 263                                               20.1
# 264                                               12.5
# 265                                                6.6
# 266                                               19.8
# 267                                                  -
#
#                                         S0801_C01_039E  \
# 0    Estimate!!Total!!Workers 16 years and over who...
# 1                                                 10.7
# 2                                                 12.5
# 3                                                 16.4
# 4                                                  3.1
# 263                                               13.5
# 264                                               18.5
# 265                                               13.5
# 266                                               18.1
# 267                                                  -
#
#                                         S0801_C01_040E  \
# 0    Estimate!!Total!!Workers 16 years and over who...
# 1                                                 13.7
# 2                                                 16.8
# 3                                                 17.0
# 4                                                  1.2
# 263                                               15.3
# 264                                               19.5
# 265                                               16.3
# 266                                               12.8
# 267                                                  -
#
#                                         S0801_C01_041E  \
# 0    Estimate!!Total!!Workers 16 years and over who...
# 1                                                  5.9
# 2                                                  5.3
# 3                                                 17.1
# 4                                                  0.6
# 263                                                9.7
# 264                                                6.2
# 265                                               10.9
# 266                                                7.5
# 267                                                  -
#
#                                         S0801_C01_042E  \
# 0    Estimate!!Total!!Workers 16 years and over who...
# 1                                                 21.2
# 2                                                 21.6
# 3                                                 14.7
# 4                                                 20.6
# 263                                               14.0
# 264                                                4.4
# 265                                               19.6
# 266                                               15.8
# 267                                                  -
#
#                                         S0801_C01_043E  \
# 0    Estimate!!Total!!Workers 16 years and over who...
# 1                                                  7.7
# 2                                                  2.5
# 3                                                  6.1
# 4                                                 15.4
# 263                                                9.6
# 264                                                7.5
# 265                                                8.7
# 266                                                1.0
# 267                                                  -
#
#                                         S0801_C01_044E  \
# 0    Estimate!!Total!!Workers 16 years and over who...
# 1                                                  0.0
# 2                                                  5.0
# 3                                                  0.0
# 4                                                 12.3
# 263                                                1.6
# 264                                                0.0
# 265                                                6.2
# 266                                                8.8
# 267                                                  -
#
#                                         S0801_C01_045E  ...  \
# 0    Estimate!!Total!!Workers 16 years and over who...  ...
# 1                                                  4.7  ...
# 2                                                  6.5  ...
# 3                                                  1.3  ...
# 4                                                 17.8  ...
# 263                                                5.7  ...
# 264                                                2.4  ...
# 265                                                7.4  ...
# 266                                                5.9  ...
# 267                                                  -  ...
#
#                                         S0801_C02_045E  \
# 0    Estimate!!Male!!Workers 16 years and over who ...
# 1                                                  6.8
# 2                                                  2.8
# 3                                                  1.6
# 4                                                 31.7
# 263                                                7.5
# 264                                                5.0
# 265                                               14.0
# 266                                                9.0
# 267                                                  -
#
#                                         S0801_C03_037E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                 35.5
# 2                                                 13.4
# 3                                                 11.6
# 4                                                 11.3
# 263                                                3.0
# 264                                               30.4
# 265                                                1.5
# 266                                                9.1
# 267                                                  -
#
#                                         S0801_C03_038E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                 10.2
# 2                                                 13.2
# 3                                                 20.6
# 4                                                  9.2
# 263                                               10.2
# 264                                                9.1
# 265                                               10.2
# 266                                               19.5
# 267                                                  -
#
#                                         S0801_C03_039E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                  8.1
# 2                                                 16.5
# 3                                                 25.3
# 4                                                  7.0
# 263                                               22.1
# 264                                               28.2
# 265                                               15.9
# 266                                               21.8
# 267                                                  -
#
#                                         S0801_C03_040E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                  6.2
# 2                                                 14.3
# 3                                                 15.8
# 4                                                  2.8
# 263                                               22.5
# 264                                               17.9
# 265                                                8.5
# 266                                               15.2
# 267                                                  -
#
#                                         S0801_C03_041E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                 11.5
# 2                                                  4.5
# 3                                                  9.0
# 4                                                  0.0
# 263                                                5.4
# 264                                                0.0
# 265                                                3.3
# 266                                                7.3
# 267                                                  -
#
#                                         S0801_C03_042E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                 22.4
# 2                                                 16.6
# 3                                                 11.1
# 4                                                 41.5
# 263                                               14.5
# 264                                                0.0
# 265                                               38.4
# 266                                               19.0
# 267                                                  -
#
#                                         S0801_C03_043E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                  3.4
# 2                                                  2.4
# 3                                                  5.5
# 4                                                 11.3
# 263                                               18.9
# 264                                               14.5
# 265                                               14.9
# 266                                                1.5
# 267                                                  -
#
#                                         S0801_C03_044E  \
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                  0.0
# 2                                                  7.3
# 3                                                  0.0
# 4                                                 16.9
# 263                                                1.3
# 264                                                0.0
# 265                                                7.3
# 266                                                3.8
# 267                                                  -
#
#                                         S0801_C03_045E
# 0    Estimate!!Female!!Workers 16 years and over wh...
# 1                                                  2.8
# 2                                                 11.8
# 3                                                  1.0
# 4                                                  0.0
# 263                                                2.2
# 264                                                0.0
# 265                                                0.0
# 266                                                2.8
# 267                                                  -
#
# [10 rows x 28 columns]

# %% [markdown]
# ### Selecting the % of vehicles

# %%
# select columns that correspond to data on average travel time to work by sex
# data can be summarized to calculate the overall average commute times within orange county

num_of_vehicles_df = commute_df_clean.loc[ :,['GEO_ID','S0801_C01_047E','S0801_C01_048E','S0801_C01_049E','S0801_C01_050E','S0801_C01_051E']]

# view dataframe to validate dataframe slice
pd.concat([num_of_vehicles_df.head(), num_of_vehicles_df.tail()])
# Out:
#                    GEO_ID                                     S0801_C01_047E  \
# 0               Geography  Estimate!!Total!!VEHICLES AVAILABLE!!Workers 1...
# 1    1400000US12095010201                                               1315
# 2    1400000US12095010202                                               2441
# 3    1400000US12095010300                                               1509
# 4    1400000US12095010400                                                331
# 263  1400000US12095018800                                               3643
# 264  1400000US12095018901                                               1519
# 265  1400000US12095018902                                               2808
# 266  1400000US12095019000                                               2256
# 267  1400000US12095990000                                                  0
#
#                                         S0801_C01_048E  \
# 0    Estimate!!Total!!VEHICLES AVAILABLE!!Workers 1...
# 1                                                  4.6
# 2                                                  0.6
# 3                                                  1.7
# 4                                                 32.9
# 263                                                1.5
# 264                                                7.1
# 265                                                0.0
# 266                                                0.9
# 267                                                  -
#
#                                         S0801_C01_049E  \
# 0    Estimate!!Total!!VEHICLES AVAILABLE!!Workers 1...
# 1                                                 56.4
# 2                                                 45.1
# 3                                                 43.1
# 4                                                 34.4
# 263                                               30.1
# 264                                               38.9
# 265                                               70.5
# 266                                               34.9
# 267                                                  -
#
#                                         S0801_C01_050E  \
# 0    Estimate!!Total!!VEHICLES AVAILABLE!!Workers 1...
# 1                                                 26.2
# 2                                                 47.1
# 3                                                 47.6
# 4                                                 32.6
# 263                                               57.6
# 264                                               48.7
# 265                                               19.5
# 266                                               42.9
# 267                                                  -
#
#                                         S0801_C01_051E
# 0    Estimate!!Total!!VEHICLES AVAILABLE!!Workers 1...
# 1                                                 12.9
# 2                                                  7.2
# 3                                                  7.6
# 4                                                  0.0
# 263                                               10.8
# 264                                                5.3
# 265                                               10.0
# 266                                               21.3
# 267                                                  -

# %%
# selecting the columns from the dataframe that correspond the vehicle data
# convert the commute times in minutes from an python object to a numerical value

numbr_cols2 = num_of_vehicles_df[['S0801_C01_047E','S0801_C01_048E','S0801_C01_049E','S0801_C01_050E','S0801_C01_051E']]

#converting values from string to float
for cols in numbr_cols2:
    try:
        num_of_vehicles_df[cols]= pd.to_numeric(num_of_vehicles_df[cols],errors = 'coerce')
    except ValueError:
        pass 

num_of_vehicles_df.dtypes
# Out:
# GEO_ID             object
# S0801_C01_047E    float64
# S0801_C01_048E    float64
# S0801_C01_049E    float64
# S0801_C01_050E    float64
# S0801_C01_051E    float64
# dtype: object

# %%
# remove the first row from the dataframe
num_of_vehicles_df.drop(0, inplace = True)

# %%
# drop all of the na values in the dataframe
num_of_vehicles_df.dropna()
# Out:
#                    GEO_ID  S0801_C01_047E  S0801_C01_048E  S0801_C01_049E  \
# 1    1400000US12095010201          1315.0             4.6            56.4
# 2    1400000US12095010202          2441.0             0.6            45.1
# 3    1400000US12095010300          1509.0             1.7            43.1
# 4    1400000US12095010400           331.0            32.9            34.4
# 5    1400000US12095010500           184.0            16.3            71.2
# ..                    ...             ...             ...             ...
# 262  1400000US12095018700          1731.0             5.7            38.3
# 263  1400000US12095018800          3643.0             1.5            30.1
# 264  1400000US12095018901          1519.0             7.1            38.9
# 265  1400000US12095018902          2808.0             0.0            70.5
# 266  1400000US12095019000          2256.0             0.9            34.9
#
#      S0801_C01_050E  S0801_C01_051E
# 1              26.2            12.9
# 2              47.1             7.2
# 3              47.6             7.6
# 4              32.6             0.0
# 5              12.5             0.0
# ..              ...             ...
# 262            30.0            26.1
# 263            57.6            10.8
# 264            48.7             5.3
# 265            19.5            10.0
# 266            42.9            21.3
#
# [265 rows x 6 columns]

# %%
# renaming the dataframe columns to meaningful names 
num_of_vehicles_df = num_of_vehicles_df.rename(columns ={'S0801_C01_047E':'Total_Workers_16plus','S0801_C01_048E':'%_No_Vehicle_Available',
                                           'S0801_C01_049E' :'%_One_Vehicle_Available','S0801_C01_050E' :'%_Two_Vehicle_Available',
                                            'S0801_C01_051E' :'%_Three_or_more_Vehicle_Available'})
num_of_vehicles_df.head()
# Out:
#                  GEO_ID  Total_Workers_16plus  %_No_Vehicle_Available  \
# 1  1400000US12095010201                1315.0                     4.6
# 2  1400000US12095010202                2441.0                     0.6
# 3  1400000US12095010300                1509.0                     1.7
# 4  1400000US12095010400                 331.0                    32.9
# 5  1400000US12095010500                 184.0                    16.3
#
#    %_One_Vehicle_Available  %_Two_Vehicle_Available  \
# 1                     56.4                     26.2
# 2                     45.1                     47.1
# 3                     43.1                     47.6
# 4                     34.4                     32.6
# 5                     71.2                     12.5
#
#    %_Three_or_more_Vehicle_Available
# 1                               12.9
# 2                                7.2
# 3                                7.6
# 4                                0.0
# 5                                0.0

# %% [markdown]
# ## Analysis

# %%
#summary statistics
avg_time_df.describe()
# Out:
#        Total_Workers_Commute_Time  Male_Workers_Commute_Time  \
# count                  266.000000                 265.000000
# mean                    28.375564                  29.520377
# std                      5.123881                   6.171946
# min                     13.900000                  13.500000
# 25%                     25.000000                  25.600000
# 50%                     28.050000                  28.900000
# 75%                     31.000000                  32.300000
# max                     53.100000                  59.700000
#
#        Female_Workers_Commute_Time
# count                   266.000000
# mean                     27.096241
# std                       6.003928
# min                      13.100000
# 25%                      23.300000
# 50%                      26.700000
# 75%                      29.800000
# max                      69.000000

# %% [markdown]
# ### Average commute time within Orange County for workers 16 and up is around 28.37 minutes, with a max time of 53 minutes.

# %%
#summary statistics
num_of_vehicles_df.describe()
# Out:
#        Total_Workers_16plus  %_No_Vehicle_Available  %_One_Vehicle_Available  \
# count            267.000000              265.000000               265.000000
# mean            2634.235955                2.958491                23.011698
# std             1277.461295                4.841317                13.415549
# min                0.000000                0.000000                 0.000000
# 25%             1787.000000                0.000000                11.900000
# 50%             2557.000000                1.000000                21.100000
# 75%             3288.500000                3.900000                31.900000
# max             9463.000000               36.600000                71.200000
#
#        %_Two_Vehicle_Available  %_Three_or_more_Vehicle_Available
# count               265.000000                         265.000000
# mean                 44.433585                          29.594717
# std                  12.372919                          14.447933
# min                   6.200000                           0.000000
# 25%                  36.300000                          18.700000
# 50%                  44.700000                          29.100000
# 75%                  53.000000                          39.300000
# max                  86.800000                          93.800000

# %% [markdown]
# ## Map plot of Commute Times

# %%
# remove the prefix '1400000US' from GEO_ID to enable data to be joined with flmap_df
avg_time_df['GEO_ID'] = avg_time_df['GEO_ID'].str.replace('1400000US', '')

# %%
# checking to make sure that the GEO_ID type is still an object
avg_time_df.dtypes
# Out:
# GEO_ID                          object
# Total_Workers_Commute_Time     float64
# Male_Workers_Commute_Time      float64
# Female_Workers_Commute_Time    float64
# dtype: object

# %%
# renaming the column GEO_ID to GEOID to match the flmap_df
avg_time_df= avg_time_df.rename(columns= {'GEO_ID' :'GEOID'})
avg_time_df.head()
# Out:
#          GEOID  Total_Workers_Commute_Time  Male_Workers_Commute_Time  \
# 1  12095010201                        22.1                       26.0
# 2  12095010202                        24.8                       20.6
# 3  12095010300                        20.7                       22.1
# 4  12095010400                        44.6                       58.1
# 5  12095010500                        38.1                       24.6
#
#    Female_Workers_Commute_Time
# 1                         18.5
# 2                         30.9
# 3                         19.1
# 4                         27.3
# 5                         44.8

# %%
# change GEOID to be numeric and check to make sure that the GEOID column is now an integer. This is out table join 
avg_time_df['GEOID'] =pd.to_numeric(avg_time_df['GEOID'])

avg_time_df.dtypes
# Out:
# GEOID                            int64
# Total_Workers_Commute_Time     float64
# Male_Workers_Commute_Time      float64
# Female_Workers_Commute_Time    float64
# dtype: object

# %%
# joining the average time dataframe with the florida map dataframe to create a dataframe to plot a density map

col_to_keep = ['GEOID','Total_Workers_Commute_Time','CENTLAT','CENTLON']

map_df = avg_time_df.merge(flmap_df, on ='GEOID', how = 'left')[col_to_keep]

display(map_df)
# Out:
#            GEOID  Total_Workers_Commute_Time    CENTLAT    CENTLON
# 0    12095010201                        22.1  28.547849 -81.372490
# 1    12095010202                        24.8  28.543585 -81.367356
# 2    12095010300                        20.7  28.534029 -81.368659
# 3    12095010400                        44.6  28.533175 -81.390856
# 4    12095010500                        38.1  28.537650 -81.389965
# ..           ...                         ...        ...        ...
# 262  12095018800                        24.5  28.563696 -81.371982
# 263  12095018901                        17.0  28.550981 -81.388438
# 264  12095018902                        29.0  28.543422 -81.378796
# 265  12095019000                        22.7  28.595842 -81.374086
# 266  12095990000                         NaN  28.621148 -81.618618
#
# [267 rows x 4 columns]

# %%
# Create a plot to analyze neighborhood info
# the lighter the color, the longer the commute time 

map_plot = map_df.hvplot.points(
    'CENTLON', 
    'CENTLAT', 
    geo=True, 
    color='Total_Workers_Commute_Time',
    cmap = 'jet',
    scale = 0.9,
    alpha=1,
    tiles = 'CartoLight',
    title = 'Average Commute Times for Workers 16+ in Orange County,Florida',
    frame_width = 700,
    frame_height = 500,
        )

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [CENTLON,CENTLAT]   (Total_Workers_Commute_Time)

# %% [markdown]
# ## Map Plot of Number of Vehicles

# %%
# remove the prefix '1400000US' from GEO_ID to enable data to be joined with flmap_df
num_of_vehicles_df['GEO_ID'] = num_of_vehicles_df['GEO_ID'].str.replace('1400000US', '')

# %%
# checking to make sure that the GEO_ID type is still an object
num_of_vehicles_df.dtypes
# Out:
# GEOID                                 object
# Total_Workers_16plus                 float64
# %_No_Vehicle_Available               float64
# %_One_Vehicle_Available              float64
# %_Two_Vehicle_Available              float64
# %_Three_or_more_Vehicle_Available    float64
# dtype: object

# %%
# renaming the column GEO_ID to GEOID to match the flmap_df
num_of_vehicles_df= num_of_vehicles_df.rename(columns= {'GEO_ID' :'GEOID'})
num_of_vehicles_df.head()
# Out:
#          GEOID  Total_Workers_16plus  %_No_Vehicle_Available  \
# 1  12095010201                1315.0                     4.6
# 2  12095010202                2441.0                     0.6
# 3  12095010300                1509.0                     1.7
# 4  12095010400                 331.0                    32.9
# 5  12095010500                 184.0                    16.3
#
#    %_One_Vehicle_Available  %_Two_Vehicle_Available  \
# 1                     56.4                     26.2
# 2                     45.1                     47.1
# 3                     43.1                     47.6
# 4                     34.4                     32.6
# 5                     71.2                     12.5
#
#    %_Three_or_more_Vehicle_Available
# 1                               12.9
# 2                                7.2
# 3                                7.6
# 4                                0.0
# 5                                0.0

# %%
# change GEOID to be numeric and check to make sure that the GEOID column is now an integer. This is out table join 
#num_of_vehicles_df['GEOID'] =pd.to_numeric(num_of_vehicles_df['GEOID'])

num_of_vehicles_df.dtypes
# Out:
# GEOID                                 object
# Total_Workers_16plus                 float64
# %_No_Vehicle_Available               float64
# %_One_Vehicle_Available              float64
# %_Two_Vehicle_Available              float64
# %_Three_or_more_Vehicle_Available    float64
# dtype: object

# %%
flmap_df.dtypes
# Out:
# MTFCC         object
# OID          float64
# GEOID          int64
# STATE          int64
# COUNTY         int64
# TRACT          int64
# BASENAME     float64
# NAME          object
# LSADC         object
# FUNCSTAT      object
# AREALAND     float64
# AREAWATER    float64
# UR           float64
# CENTLAT      float64
# CENTLON      float64
# INTPTLAT     float64
# INTPTLON     float64
# dtype: object

# %%
# change GEOID to be numeric and check to make sure that the GEOID column is now an integer. This is out table join 
num_of_vehicles_df['GEOID'] =pd.to_numeric(num_of_vehicles_df['GEOID'])

num_of_vehicles_df.dtypes
# Out:
# GEOID                                  int64
# Total_Workers_16plus                 float64
# %_No_Vehicle_Available               float64
# %_One_Vehicle_Available              float64
# %_Two_Vehicle_Available              float64
# %_Three_or_more_Vehicle_Available    float64
# dtype: object

# %%
# joining the average time dataframe with the florida map dataframe to create a dataframe to plot a density map

col_to_keep2 = ['GEOID','%_Two_Vehicle_Available','CENTLAT','CENTLON']

map_df2 = num_of_vehicles_df.merge(flmap_df, on ='GEOID', how = 'left')[col_to_keep2]

display(map_df2)
# Out:
#            GEOID  %_Two_Vehicle_Available    CENTLAT    CENTLON
# 0    12095010201                     26.2  28.547849 -81.372490
# 1    12095010202                     47.1  28.543585 -81.367356
# 2    12095010300                     47.6  28.534029 -81.368659
# 3    12095010400                     32.6  28.533175 -81.390856
# 4    12095010500                     12.5  28.537650 -81.389965
# ..           ...                      ...        ...        ...
# 262  12095018800                     57.6  28.563696 -81.371982
# 263  12095018901                     48.7  28.550981 -81.388438
# 264  12095018902                     19.5  28.543422 -81.378796
# 265  12095019000                     42.9  28.595842 -81.374086
# 266  12095990000                      NaN  28.621148 -81.618618
#
# [267 rows x 4 columns]

# %%
# Create a plot to analyze neighborhood info
map_plot2 = map_df2.hvplot.points(
    'CENTLON', 
    'CENTLAT', 
    geo=True, 
    color='%_Two_Vehicle_Available',
    cmap = 'jet',
    scale = 0.9,
    alpha=1,
    tiles = 'CartoLight',
    title = '% of Households with Two Vehicles Available in Orange County,Florida',
    frame_width = 700,
    frame_height = 500,
        )

map_plot2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [CENTLON,CENTLAT]   (%_Two_Vehicle_Available)

# %%
provider_df.groupby('City').count()
# Out:
#                 TIGER OUTPUT ADDRESS  State  Zip  LON  LAT
# City
#  APOPKA                           32     32   32   32   32
#  KISSIMMEE                         1      1    1    1    1
#  MAITLAND                          8      8    8    8    8
#  MOUNT DORA                        2      2    2    2    2
#  OAKLAND                           1      1    1    1    1
#  OCOEE                            16     16   16   16   16
#  ORLANDO                         484    484  484  484  484
#  SAINT CLOUD                       1      1    1    1    1
#  WINDERMERE                       10     10   10   10   10
#  WINTER GARDEN                    23     23   23   23   23
#  WINTER PARK                      27     27   27   27   27
#  ZELLWOOD                          1      1    1    1    1
